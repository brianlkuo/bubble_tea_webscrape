# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
df1 = pd.read_csv('bubbleteaNY.csv') 
df1['search_city'] = 'New York'
df2 = pd.read_csv('bubbleteaLA.csv') 
df2['search_city'] = 'Los Angeles'
df3 = pd.read_csv('bubbleteaCHI.csv') 
df3['search_city'] = 'Chicago'
df4 = pd.read_csv('bubbleteaHOU.csv') 
df4['search_city'] = 'Houston'
df5 = pd.read_csv('bubbleteaPHX.csv') 
df5['search_city'] = 'Phoenix'
df6 = pd.read_csv('bubbleteaPHIL.csv') 
df6['search_city'] = 'Philadelphia'
df7 = pd.read_csv('bubbleteaSanAnt.csv') 
df7['search_city'] = 'San Antonio'
df8 = pd.read_csv('bubbleteaSD.csv') 
df8['search_city'] = 'San Diego'
df9 = pd.read_csv('bubbleteaDallas.csv') 
df9['search_city'] = 'Dallas'
df10 = pd.read_csv('bubbleteaSJ.csv') 
df10['search_city'] = 'San Jose'

bubbleteaTop10 = pd.concat([df1, df2, df3, df4, df5, df6, df7,
                           df8, df9, df10], sort=True)
col_order = ['search_city', 'business_name', 'rating','food_tags', 'first_review_date', 
       'last_review_date', 'review_num', 'address','city','state', 'street', 'zip5']

bubbleteaTop10 = bubbleteaTop10[col_order]
bubbleteaTop10.to_csv(r'bubbleteaTop10.csv',index=True)

# %%
cities = pd.read_csv('bubbleteaTop10.csv')
cities = cities.astype({'zip5': 'object'})
cities = cities.loc[:, ~cities.columns.str.contains('^Unnamed')]

# only with bubble tag and have at least 1 review

cities = cities[(cities.food_tags.str.contains('Bubble Tea')) &
               (cities.first_review_date != 0)]
# cities.dtypes

# %%
# add first revew year and month
cities['start_year'] = cities.first_review_date.str[-4:]
cities['start_month'] = cities.first_review_date.str.split('/', expand = True).iloc[:,0]

# %%
# new business count by year
year_cnt = cities.groupby('start_year')['business_name'].agg(['count'])
sns.set_style("white")
plt.figure(figsize=(10, 5))
new_biz = sns.lineplot(data=year_cnt)
plt.title('Annual New Business Count')
new_biz.set(xlabel='Year', ylabel='Count of New Business')
# Out:
# [Text(0,0.5,'Count of New Business'), Text(0.5,0,'Year')]

# %%
# new business count by year and city
year_cnt_city = cities.groupby(['start_year','search_city']).count()\
.business_name.unstack()
year_cnt_city = year_cnt_city.fillna(0)
# year_cnt_city.plot()
sns.set_style("white")
plt.figure(figsize=(10, 5))
year_city = sns.lineplot(data=year_cnt_city, dashes = False)
plt.title('Annual New Business by City')
year_city.set(xlabel='Year', ylabel='Count of New Business')
# Out:
# [Text(0,0.5,'Count of New Business'), Text(0.5,0,'Year')]

# %%
# Total reviews and average rating by searched city:
city_comp = cities.groupby('search_city').agg({'rating':'mean', \
                                   'review_num':'sum',\
                                   'address':'count'})
# city_comp['avg_rating'] = city_comp.pop['rating']
city_comp = city_comp.rename(columns = {'rating':'avg_rating',
                            'review_num':'tot_rev',
                            'address':'loc_cnt'})
city_comp['avg_rev_per_loc'] = city_comp.tot_rev/city_comp.loc_cnt
city_comp = city_comp.sort_values('loc_cnt', ascending = False)
city_comp
# in general higher location count has higher average review 
# per location
# but LA is different
# Out:
#               avg_rating  tot_rev  loc_cnt  avg_rev_per_loc
# search_city
# San Jose        3.700000  56004.0      210       266.685714
# New York        3.873786  21778.0      206       105.718447
# Houston         3.840206  20857.0      196       106.413265
# Dallas          3.789474  17952.0      162       110.814815
# Los Angeles     3.906780  38298.0      121       316.512397
# Chicago         3.797753   8799.0       89        98.865169
# Phoenix         3.807692  11745.0       81       145.000000
# Philadelphia    3.797101   5173.0       72        71.847222
# San Antonio     4.027027   3482.0       38        91.631579
# San Diego       3.600000   4389.0       25       175.560000

# %%
LA =  cities[cities.search_city == 'Los Angeles'].\
groupby(['start_year']).agg({'address':'count'})
LA = LA.rename(columns = {'address':'new_stores'})
LA = LA.sort_values('start_year').plot(kind = 'bar')

# plt.figure(figsize=(10, 5))
plt.title('Annual New Business in LA')
LA.set(xlabel='Year', ylabel='Count of New Business')
plt.show()

# %%
#checking out LA
cities[cities.search_city == 'Los Angeles']
LA =  cities[cities.search_city == 'Los Angeles'].\
groupby(['start_year']).agg({'address':'count'})
LA = LA.rename(columns = {'address':'new_stores'})

# year_cnt_city.plot()
sns.set_style("white")
plt.figure(figsize=(10, 5))
LA_plt = sns.lineplot(data=LA, dashes = False)
plt.title('Annual New Business by Top Businesses')
LA_plt.set(xlabel='Year', ylabel='Count of New Business')
plt.show()

# %%
# growth rate
year_cnt = cities.groupby('start_year', 'search_city')['business_name'].agg(['business_name':'count'])
# year_cnt['Difference'] = year_cnt.diff()
year_cnt['Growth_Rate'] = year_cnt['Difference']/(year_cnt['count'].astype(float)-year_cnt['Difference'])
year_cnt
# Out:
#   File "<ipython-input-670-616371019bf3>", line 2
#     year_cnt = cities.groupby('start_year', 'search_city')['business_name'].agg(['business_name':'count'])
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
year_cnt['Difference']/(year_cnt['count'].astype(float)-year_cnt['Difference'])
# Out:
# start_year
# 2004         NaN
# 2005    4.000000
# 2006    0.800000
# 2007    0.500000
# 2008   -0.481481
# 2009    0.214286
# 2010   -0.529412
# 2011    1.500000
# 2012    0.050000
# 2013    0.904762
# 2014    0.675000
# 2015    0.000000
# 2016    0.626866
# 2017    0.302752
# 2018    0.380282
# 2019    0.464286
# 2020   -0.282230
# dtype: float64

# %%
#count word tags
str = "this is string example....wow!!!";

sub = "i";
print ("str.count(sub, 4, 40) : ", str.count(sub, 0, len(str)))
sub = "wow";
print ("str.count(sub) : ", str.count(sub))
# Out:
# str.count(sub, 4, 40) :  3
# str.count(sub) :  1

# %%
# Store count by state: skewed...
sns.countplot(x ='state',  data = cities, order = cities['state'].value_counts().index,
             color = "tab:blue") 
  
# Show the plot 
plt.show()

# %%
zip_cnt = cities.groupby(['zip5']).count().business_name
zip_cnt = zip_cnt.reset_index(name='count') \
    .sort_values(['count'], ascending=False).head(20)
zip_cnt.dtypes
# Out:
# zip5     int64
# count    int64
# dtype: object

# %%
zip_cnt
# Out:
#       zip5  count
# 241  77036     20
# 479  95035     16
# 495  95122     16
# 26   10013     14
# 476  95014     13
# 259  77072     13
# 18   10003     12
# 187  75075     11
# 76   11354     10
# 58   11201     10
# 283  77433     10
# 496  95123     10
# 481  95050      9
# 148  60616      9
# 489  95112      9
# 101  19107      9
# 167  75023      9
# 501  95129      9
# 17   10002      8
# 68   11220      8

# %%
# count by zipcode
zip_cnt = cities.groupby(['zip5']).count().business_name
zip_cnt = zip_cnt.reset_index(name='count') \
    .sort_values(['count'], ascending=False).head(20)

plt.figure(figsize=(10, 5))
zip_count = zip_cnt.plot(x = 'zip5', y = 'count', kind ='bar', 
                         color = 'tab:blue')
#sns.set_style("white")
# year_city = sns.barplot(data=zip_cnt)
plt.title('Top 20 Zip Codes')
zip_count.set(xlabel='Zip Codes', ylabel='Count of Business')
# Out:
# [Text(0,0.5,'Count of Business'), Text(0.5,0,'Zip Codes')]

# %%
# 77036: Houston's China town
# 95035: Milpitas
# 95122: East San Jose
# 10013: lower Manhattan
# 95014: Cupertino
# 77072: Houston area with a lot of Chinese restaurants
# 10003: Left part of East village
# 75075: Houston area with a lot of Chinese restaurants

# %%
# business count:
business_cnt = cities.groupby(['business_name']).count().address
business_cnt = business_cnt.reset_index(name='count') \
    .sort_values(['count'], ascending=False)

biz_cnt = business_cnt.head(20).plot(x = 'business_name', y = 'count', kind ='barh', 
                         color = 'tab:blue')
plt.title('Top 20 Chains')
biz_cnt.set(xlabel='Store Count', ylabel='Chain')
plt.show()

# %%
# Top 10 businesses branches vs all: 16% of all stores
print(sum(business_cnt.head(10)['count']))
print(sum(business_cnt['count']))

sum(business_cnt.head(20)['count'])/sum(business_cnt['count'])
# Out:
# 187
# 1200
# 0.20333333333333334

# %%
# top 10 bubble tea branches: new branches by year
top_biz = business_cnt.business_name.head(10)

top_biz_info = cities[cities['business_name'].isin(top_biz)]

biz_yr_cnt =  top_biz_info.groupby(['start_year','business_name']).count()\
.address.unstack()
biz_yr_cnt = biz_yr_cnt.fillna(0)
# year_cnt_city.plot()
sns.set_style("white")
plt.figure(figsize=(10, 5))
biz_yr_cnt = sns.lineplot(data=biz_yr_cnt, dashes = False)
plt.title('Annual New Business by Top Chains')
biz_yr_cnt.set(xlabel='Year', ylabel='Count of New Business')
plt.show()

# %%
# top 10 bubble tea branches: new branches by month
top_biz = business_cnt.business_name.head(10)

top_biz_info = cities[cities['business_name'].isin(top_biz)]

biz_mo_cnt =  top_biz_info.groupby(['start_month']).count().\
address.sort_values('start_month')
# biz_yr_cnt = biz_yr_cnt.fillna(0)

# year_cnt_city.plot()
sns.set_style("white")
plt.figure(figsize=(10, 5))
biz_mo_cnt = sns.lineplot(data=biz_mo_cnt, dashes = False)
plt.title('Annual New Business by Top Chains')
biz_mo_cnt.set(xlabel='Month', ylabel='Count of New Business')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-690-eb25a2ee8168> in <module>()
#       4 top_biz_info = cities[cities['business_name'].isin(top_biz)]
#       5
# ----> 6 biz_mo_cnt =  top_biz_info.groupby(['start_month']).count().address.sort_values('start_month')
#       7 # biz_yr_cnt = biz_yr_cnt.fillna(0)
#       8
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    2442         """
#    2443         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 2444         axis = self._get_axis_number(axis)
#    2445
#    2446         # GH 5856/5853
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     372                 pass
#     373         raise ValueError('No axis named {0} for object type {1}'
# --> 374                          .format(axis, type(self)))
#     375
#     376     def _get_axis_name(self, axis):
#
# ValueError: No axis named start_month for object type <class 'pandas.core.series.Series'>

# %%
# rating of top business vs lower

top_biz = business_cnt.business_name.head(10)
top_biz_info = cities[cities['business_name'].isin(top_biz)]

lower_biz = business_cnt.business_name.tail(10)
lower_biz_info = cities[cities['business_name'].isin(lower_biz)]

top_rating = top_biz_info.groupby('business_name').mean()
lower_rating = lower_biz_info.groupby('business_name').mean()

print(top_rating)
print(lower_rating)


# observation: chains tend to have more reviews, 
# but average rating are not necessarily higher
# Out:
#                               rating  review_num
# business_name
# BAMBU                       3.636364  198.090909
# Gong Cha                    3.806452  157.677419
# Happy Lemon                 4.000000  238.153846
# Kung Fu Tea                 3.477273  170.181818
# Sharetea                    3.772727  161.727273
# Tapioca Express             3.083333  180.444444
# Tastea                      4.000000  236.666667
# The Teahouse Tapioca & Tea  3.700000  146.300000
# Vivi Bubble Tea             3.578947  132.052632
# Zero Degrees                3.266667  191.066667
#                                        rating  review_num
# business_name
# Hien Khanh                                4.0        96.0
# High Tea House                            4.0        11.0
# Hippies Brew                              4.0       178.0
# Hitea                                     4.0         7.0
# Ho Ho Té                                  4.0       107.0
# Hoja Bubble Tea And Asian Street Food     4.0        52.0
# Hole-y Boba & Donuts                      3.0        78.0
# Home                                      3.0        67.0
# Honey Creme                               3.0       171.0
# ÜMACHA                                    4.0        57.0

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x = 'start_year', data = cities, order = cities['start_year'].value_counts().index, 
             color = 'tab:blue')
plt.show()

# %%
# Out:
#                  business_name  rating  \
# 0             Surreal Creamery     4.0
# 1  Creep City Ninja Bubble Tea     3.0
# 2                    Namas Tea     5.0
# 3       Coco Fresh Tea & Juice     3.0
# 4   Hawa smoothie & Bubble tea     5.0
#
#                                        food_tags first_review_date  \
# 0           Ice Cream & Frozen Yogurt/Bubble Tea          6/6/2020
# 1    Bubble Tea/Vietnamese/Venues & Event Spaces         6/17/2018
# 2  Coffee & Tea/Bubble Tea/Venues & Event Spaces         6/28/2019
# 3                                     Bubble Tea          3/1/2013
# 4              Bubble Tea/Juice Bars & Smoothies        10/29/2019
#
#   last_review_date  review_num                                        address  \
# 0       10/24/2020       115.0                 538 2nd Ave,New York, NY 10016
# 1        7/25/2020        27.0  265 Graham Ave,Store Front,Brooklyn, NY 11206
# 2         9/1/2020        19.0             863 Sterling Pl,Brooklyn, NY 11216
# 3       10/24/2020        64.0              86-55 Broadway,Elmhurst, NY 11373
# 4        9/18/2020         8.0                1151 2nd Ave,New York, NY 10065
#
#        city state           street   zip5 start_year start_month
# 0  New York    NY      538 2nd Ave  10016       2020           6
# 1  Brooklyn    NY   265 Graham Ave  11206       2018          17
# 2  Brooklyn    NY  863 Sterling Pl  11216       2019          28
# 3  Elmhurst    NY   86-55 Broadway  11373       2013           1
# 4  New York    NY     1151 2nd Ave  10065       2019          29
